# %%
import polars as pl

df = pl.read_csv('./airline_route_profitability.csv')

df.head()
# Out:
# shape: (5, 33)
# ┌────────────┬────────────┬────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Flight_Num ┆ Flight_Dat ┆ Origin ┆ Destinati ┆ … ┆ IT_System ┆ Total_Cos ┆ Profit    ┆ Profit_Ma │
# │ ber        ┆ e          ┆ ---    ┆ on        ┆   ┆ s_Cost    ┆ t         ┆ ---       ┆ rgin      │
# │ ---        ┆ ---        ┆ str    ┆ ---       ┆   ┆ ---       ┆ ---       ┆ f64       ┆ ---       │
# │ str        ┆ str        ┆        ┆ str       ┆   ┆ f64       ┆ f64       ┆           ┆ f64       │
# ╞════════════╪════════════╪════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ EK8960     ┆ 2024-12-20 ┆ DXB    ┆ ORD       ┆ … ┆ 3769.37   ┆ 506421.77 ┆ -42204.34 ┆ -9.09     │
# │ EK3960     ┆ 2024-05-13 ┆ DXB    ┆ HYD       ┆ … ┆ 1937.81   ┆ 123323.88 ┆ 40261.57  ┆ 24.61     │
# │ EK7529     ┆ 2024-10-12 ┆ DXB    ┆ CDG       ┆ … ┆ 3415.99   ┆ 282266.09 ┆ 399299.1  ┆ 58.59     │
# ...

# %%
df.null_count() # {"Ancillary_Revenue": 271, "Catering_Cost": 265, "Handling_Cost": 256}
# Out:
# shape: (1, 33)
# ┌────────────┬────────────┬────────┬────────────┬───┬────────────┬────────────┬────────┬───────────┐
# │ Flight_Num ┆ Flight_Dat ┆ Origin ┆ Destinatio ┆ … ┆ IT_Systems ┆ Total_Cost ┆ Profit ┆ Profit_Ma │
# │ ber        ┆ e          ┆ ---    ┆ n          ┆   ┆ _Cost      ┆ ---        ┆ ---    ┆ rgin      │
# │ ---        ┆ ---        ┆ u32    ┆ ---        ┆   ┆ ---        ┆ u32        ┆ u32    ┆ ---       │
# │ u32        ┆ u32        ┆        ┆ u32        ┆   ┆ u32        ┆            ┆        ┆ u32       │
# ╞════════════╪════════════╪════════╪════════════╪═══╪════════════╪════════════╪════════╪═══════════╡
# │ 0          ┆ 0          ┆ 0      ┆ 0          ┆ … ┆ 0          ┆ 0          ┆ 0      ┆ 0         │
# └────────────┴────────────┴────────┴────────────┴───┴────────────┴────────────┴────────┴───────────┘
